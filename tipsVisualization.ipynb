# %%
import pandas as pd
import missingno as msno
import matplotlib.pyplot as plt

df = pd.read_csv('tips.csv', encoding='latin1')

# %%
#kaggle Tipster Visualization

import numpy as np
odds = (df
            .pivot(index='UID', columns='Tipster', values='Odds')
            .assign(ID=df.ID)
            .fillna(0)
            .groupby('ID')
            .sum()
            .assign(Win=df.Result.map(lambda v: v == 'Win'))
            .replace(0, np.nan))

odds.head()
# Out:
# Tipster  Tipster A  Tipster A1  Tipster B  Tipster B1  Tipster C  Tipster C1  \
# ID
# 0.0            NaN         NaN        NaN         NaN        NaN         NaN
# 1.0           1.25       19.40       2.75        3.75       13.0        6.00
# 2.0           8.00        6.50       1.91        2.38        4.5       12.10
# 3.0           4.50        8.00       9.00        8.00       15.0        2.75
# 4.0           7.00        3.75       1.91       13.00       10.0        5.00
#
# Tipster  Tipster D  Tipster D1  Tipster E  Tipster E1  ...  Tipster R  \
# ID                                                     ...
# 0.0            NaN         NaN        NaN        5.00  ...        NaN
# 1.0           26.0        15.0       5.50         NaN  ...       4.50
# 2.0          135.0        22.0       3.00        4.00  ...       1.36
# 3.0           10.0        50.0       1.88        3.25  ...       4.00
# 4.0           42.0        28.0       4.50        4.50  ...       1.40
#
# ...

# %%
#kaggle Visualization

msno.matrix(odds.drop('Win', axis='columns').sample(500))

# %%
msno.bar(odds.drop('Win', axis='columns'))

# %%
msno.heatmap(odds.drop('Win', axis='columns'))

# %%
#minha tentativa de visualização

df_cleaned = df.dropna(axis=1)  
odds_cleaned = (df_cleaned
            .pivot(index='UID', columns='Tipster', values='Odds')
            .assign(ID=df_cleaned.ID)
            .fillna(0)
            .groupby('ID')
            .sum()
            .assign(Win=df_cleaned.Result.map(lambda v: v == 'Win'))
            .replace(0, np.nan))
msno.matrix(odds_cleaned)
plt.show()
